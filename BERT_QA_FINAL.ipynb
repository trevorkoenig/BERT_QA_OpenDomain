# %%
# AnswerResult will hold the bert answers for ease of scalability
class AnswerResult:
    def __init__(self, answer, score=0.0, source_sentence=None):
        self.answer = answer
        self.score = score

    def __repr__(self):
        return f"AnswerResult(text='{self.answer}', score={self.score:.4f}')"

    def is_valid(self):
        return self.answer and self.answer.upper() != "NO ANSWER FOUND"

    def get_answer(self):
        return self.answer

    @staticmethod
    def no_answer():
        return AnswerResult("NO ANSWER FOUND", 0.0, None)

# %% [markdown]
# # Import the model

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from transformers import AutoTokenizer, AutoModelForQuestionAnswering

model_path = "/content/drive/MyDrive/CISC 688 - Intro to NLP /Project - CISC 688 - Intro to NLP/NLP_BERT_Model"
tokenizer = AutoTokenizer.from_pretrained(model_path)
model = AutoModelForQuestionAnswering.from_pretrained(model_path)

# %% [markdown]
# # Test Set

# %%
dataset = [
    "What is the capital of France?",
    "Who wrote the novel '1984'?",
    "What is the largest planet in the Solar System?",
    "In which year did World War II end?",
    "Who painted the Mona Lisa?",
    "What is the chemical symbol for gold?",
    "Who discovered penicillin?",
    "What is the smallest country in the world by area?",
    "What is the currency of Japan?",
    "Who was the first person to walk on the moon?",
    "What is the tallest mountain on Earth?",
    "Which element has the atomic number 1?",
    "What is the largest mammal on Earth?",
    "Who developed the theory of relativity?",
    "What is the capital city of Canada?",
    "What is the longest river in the world?",
    "Who invented the telephone?",
    "What is the official language of Brazil?",
    "Which country hosted the 2016 Summer Olympics?",
    "What is the fastest land animal?",
    "Who is known as the father of modern physics?",
    "Which continent is the Sahara Desert located in?",
    "Who was the first President of the United States?",
    "What is the main ingredient in guacamole?",
    "What is the largest ocean on Earth?",
    "Who directed the movie 'Titanic'?",
    "What is the boiling point of water at sea level in Celsius?",
    "What country is known as the Land of the Rising Sun?",
    "Who wrote 'To Kill a Mockingbird'?",
    "What is the hardest natural substance on Earth?",
    "Who is the author of 'Harry Potter'?",
    "What is the currency used in the United Kingdom?",
    "Who painted the ceiling of the Sistine Chapel?",
    "What is the main gas found in Earth's atmosphere?",
    "Which country is famous for the Great Wall?",
    "Who discovered gravity according to legend?",
    "What is the largest desert in the world?",
    "What is the capital of Australia?",
    "Who is the Greek god of the sea?",
    "What is the square root of 64?",
    "What is the longest bone in the human body?",
    "Who composed the 'Fifth Symphony'?",
    "What is the largest island in the world?",
    "What is the smallest prime number?",
    "Who was the first woman to win a Nobel Prize?",
    "Which planet is known as the Red Planet?",
    "What is the largest continent by area?",
    "Who invented the World Wide Web?",
    "What is the primary language spoken in Egypt?",
    "What is the capital of Italy?",
]

# %% [markdown]
# # Run Inference, convert span to text

# %%
# !pip install wikipedia
# Out:
# Requirement already satisfied: wikipedia in /usr/local/lib/python3.11/dist-packages (1.4.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from wikipedia) (4.13.4)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from wikipedia) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2025.4.26)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->wikipedia) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->wikipedia) (4.13.2)

# %% [markdown]
# # BERT stuff

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

def find_sentence_for_span(span_text, context):
    # """
    # Attempts to find the full sentence in the context that contains the span text.
    # Returns the sentence or None if not found.
    # """
    # doc = nlp(context)
    # for sent in doc.sents:
    #     if span_text in sent.text:
    #         return sent.text.strip()
    return None

# %%
import torch
import torch.nn.functional as F

def score_spans_in_chunk(ids, offsets, sequence_ids, start_probs, end_probs, context, tokenizer):
    best_score = 0.2  # Thresholding
    best_result = AnswerResult.no_answer()

    for start_idx in range(len(ids)):
        for end_idx in range(start_idx, min(start_idx + 15, len(ids))):
            if sequence_ids[start_idx] != 1 or sequence_ids[end_idx] != 1:
                continue
            if offsets[start_idx] is None or offsets[end_idx] is None:
                continue
            if offsets[start_idx][0] is None or offsets[end_idx][1] is None:
                continue

            span_length = end_idx - start_idx + 1
            penalty = 1.0 if span_length < 5 else 1.0 - (span_length / len(ids))
            score = start_probs[start_idx] * end_probs[end_idx] * penalty

            if score > best_score and offsets[start_idx][0] < offsets[end_idx][1]:
                start_char = offsets[start_idx][0]
                end_char = offsets[end_idx][1]
                text = context[start_char:end_char].strip().lower().title()
                best_score = score
                best_result = AnswerResult(text, score.item())

    if best_result.is_valid():
        best_result.source_sentence = find_sentence_for_span(best_result.answer, context)
    return best_result

# %%
def process_chunk(ids, attention_mask, token_type_ids, sequence_ids, offsets, context, tokenizer, model):
    with torch.no_grad():
        outputs = model(
            input_ids=ids.unsqueeze(0),
            attention_mask=attention_mask.unsqueeze(0),
            token_type_ids=token_type_ids.unsqueeze(0),
        )

    start_logits = outputs.start_logits[0]
    end_logits = outputs.end_logits[0]

    start_probs = F.softmax(start_logits, dim=0)
    end_probs = F.softmax(end_logits, dim=0)

    best_result = score_spans_in_chunk(ids, offsets, sequence_ids, start_probs, end_probs, context, tokenizer)

    if best_result.is_valid():
        print(best_result)
    return best_result

# %%
def answer_long_context_with_logs(question, context, tokenizer, model, max_length=384, doc_stride=128):
    """
    Process a long context by sliding window and returning the best AnswerResult.
    """
    inputs = tokenizer(
        question,
        context,
        max_length=max_length,
        truncation="only_second",
        stride=doc_stride,
        return_overflowing_tokens=True,
        return_offsets_mapping=True,
        padding="max_length",
        return_tensors="pt",
        return_token_type_ids=True,
    )

    input_ids = inputs["input_ids"]
    attention_mask = inputs["attention_mask"]
    offset_mappings = inputs["offset_mapping"]
    token_type_ids = inputs["token_type_ids"]

    print(f"🔍 Total chunks to evaluate: {len(input_ids)}")
    all_results = []

    # foreach chunk
    for i in range(len(input_ids)):
        # get best result
        result = process_chunk(
            input_ids[i],
            attention_mask[i],
            token_type_ids[i],
            inputs.sequence_ids(i),
            offset_mappings[i],
            context,
            tokenizer,
            model
        )

        if result.is_valid():
            all_results.append(result)

    # return answers with scores
    return all_results

# %% [markdown]
# # Wikipedia stuff

# %%
# !pip install wikipedia-api
# Out:
# Requirement already satisfied: wikipedia-api in /usr/local/lib/python3.11/dist-packages (0.8.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from wikipedia-api) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->wikipedia-api) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->wikipedia-api) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->wikipedia-api) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->wikipedia-api) (2025.4.26)

# %%
import wikipediaapi

# Setup Wikipedia API client with a proper User-Agent
user_agent = "BERT-QA-Pipeline/1.0 (contact: your-email@example.com)"
wiki_api = wikipediaapi.Wikipedia(user_agent=user_agent, language='en')

def get_key_with_max_value(my_dict):
    """Returns the key with the maximum value in a dictionary."""
    if not my_dict:
        return None
    return max(my_dict, key=my_dict.get)

def ask_question_to_wiki(question: str, tokenizer, model, topN: int = 3):
    """
    Searches Wikipedia using wikipediaapi and extracts answers using the provided tokenizer and model.
    """
    import wikipedia  # Only for search
    search_results = wikipedia.search(question, results=topN)
    print(f"Found the following relevant Wikipedia documents: {search_results}\n")

    results = []  # List of all answers
    answers = {}  # Scored key:value pairs on AnswerString:ConfidenceScore

    for title in search_results:
        print(f"🔍 Attempting to fetch page: {title}")
        page = wiki_api.page(title)

        if not page.exists():
            print(f"⚠️ Skipping '{title}' - Page does not exist or is disambiguation.")
            continue

        print(f"📄 Page Retrieved: {page.title} (Page ID: {page.pageid})")
        content = page.text.strip()

        if not content or len(content) < 50:
            print(f"⚠️ Skipping '{page.title}' due to insufficient content.")
            continue

        results += answer_long_context_with_logs(question, content, tokenizer, model)

    # softmax magic time
    scores_tensor = torch.tensor([r.score for r in results])
    softmaxed_scores = torch.nn.functional.softmax(scores_tensor, dim=0)

    for i, result in enumerate(results):
        key = result.answer
        weighted_score = softmaxed_scores[i].item()  # Convert tensor to float

        if key in answers:
            answers[key] += weighted_score
        else:
            answers[key] = weighted_score

    if not answers:
        print("❌ No valid answers found in any pages.")
        return None

    best_answer_key = get_key_with_max_value(answers)
    print(f"🏆 Best answer: {best_answer_key} with score {answers[best_answer_key]:.4f}")
    return best_answer_key

# %% [markdown]
# # Evaluation

# %%
# !pip install openai
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.11/dist-packages (1.76.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.9.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from openai) (2.11.4)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.11/dist-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.11/dist-packages (from openai) (4.13.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (0.4.0)

# %%
import openai

openaiapikey = None  # your_key_here

# Define the OpenAI client first
client = openai.OpenAI(api_key=openaiapikey)

def ask_chatgpt(question, model="gpt-3.5-turbo"):
    """Ask ChatGPT a question and return the response."""
    response = client.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": question}],
        temperature=0.7,
        max_tokens=500,
    )
    return response.choices[0].message.content.strip()

# %%
import csv

csvpath = "/content/drive/MyDrive/CISC 688 - Intro to NLP /Project - CISC 688 - Intro to NLP/answeredQs.csv"

def export_answers_to_csv(questions, tokenizer, model, csvpath, chatgpt_func):
    """
    Exports BERT and ChatGPT answers for a list of questions to a CSV file.
    """
    with open(csvpath, 'w', newline='', encoding='utf-8') as csvfile:
        csvwriter = csv.writer(csvfile, delimiter='|', quotechar='"', quoting=csv.QUOTE_MINIMAL)
        csvwriter.writerow(['question', 'BERT_Ans', 'ChatGPT_Ans'])

        for question in questions:
            print(f"\n❓ Question: {question}")

            # Get ChatGPT answer
            ChatGPTAnswer = chatgpt_func(question)

            # Get BERT answer from Wikipedia
            BERTanswer = ask_question_to_wiki(question, tokenizer, model)

            # Fallback if no BERT answer found
            if BERTanswer is None:
                BERTanswer = "No valid Wikipedia answer found"

            # Log and write the result
            output = [question, BERTanswer, ChatGPTAnswer]
            print(f"✅ Exporting: {output}")
            csvwriter.writerow(output)

# %%
# Put in csv
export_answers_to_csv(dataset, tokenizer, model, csvpath, ask_chatgpt)
# Out:
# ❓ Question: What is the capital of France?
# Found the following relevant Wikipedia documents: ['Closed-ended question', 'France', 'What Is a Nation?']
#
# 🔍 Attempting to fetch page: Closed-ended question
# 📄 Page Retrieved: Closed-ended question (Page ID: 11517229)
# 🔍 Total chunks to evaluate: 4
# AnswerResult(text='Lyon', score=0.9316')
# 🔍 Attempting to fetch page: France
# 📄 Page Retrieved: France (Page ID: 5843419)
# 🔍 Total chunks to evaluate: 76
# AnswerResult(text='Paris', score=0.9906')
# AnswerResult(text='Lyon', score=0.4889')
# AnswerResult(text='Paris', score=0.2286')
# AnswerResult(text='Paris', score=0.9708')
# AnswerResult(text='Palace Of Versailles', score=0.3331')
# AnswerResult(text='Lisbon', score=0.9907')
# AnswerResult(text='Corsica', score=0.2284')
# AnswerResult(text='Paris', score=0.9680')
# AnswerResult(text='Marseille', score=0.3075')
# AnswerResult(text='Canal Du Midi', score=0.4132')
# AnswerResult(text='Paris', score=0.6612')
# AnswerResult(text='Paris', score=0.5766')
# AnswerResult(text='Paris', score=0.4767')
# AnswerResult(text='Saint-Denis', score=0.7958')
# AnswerResult(text='Grenoble', score=0.5282')
# 🔍 Attempting to fetch page: What Is a Nation?
# 📄 Page Retrieved: What Is a Nation? (Page ID: 30455953)
# 🔍 Total chunks to evaluate: 9
# 🏆 Best answer: Paris with score 0.4717
# ✅ Exporting: ['What is the capital of France?', 'Paris', 'The capital of France is Paris.']
#
# ❓ Question: Who wrote the novel '1984'?
# Found the following relevant Wikipedia documents: ['Nineteen Eighty-Four', '1984 (2023 film)', 'Murder, She Wrote']
#
# 🔍 Attempting to fetch page: Nineteen Eighty-Four
# 📄 Page Retrieved: Nineteen Eighty-Four (Page ID: 23454753)
# 🔍 Total chunks to evaluate: 51
# AnswerResult(text='George Orwell', score=0.9702')
# AnswerResult(text='Peter Davison', score=0.6073')
# AnswerResult(text='Emmanuel Goldstein', score=0.2673')
# AnswerResult(text='Borges', score=0.3765')
# AnswerResult(text='Rex Warner', score=0.2497')
# AnswerResult(text='George Orwell', score=0.9746')
# 🔍 Attempting to fetch page: 1984 (2023 film)
# 📄 Page Retrieved: 1984 (2023 film) (Page ID: 75428384)
# 🔍 Total chunks to evaluate: 3
# AnswerResult(text='George Orwell', score=0.2477')
# AnswerResult(text='George Orwell', score=0.9548')
# 🔍 Attempting to fetch page: Murder, She Wrote
# 📄 Page Retrieved: Murder, She Wrote (Page ID: 170683)
# 🔍 Total chunks to evaluate: 20
# 🏆 Best answer: George Orwell with score 0.6091
# ✅ Exporting: ["Who wrote the novel '1984'?", 'George Orwell', "'1984' was written by George Orwell."]
#
# ❓ Question: What is the largest planet in the Solar System?
# Found the following relevant Wikipedia documents: ['Solar System', 'Ice planet', 'List of gravitationally rounded objects of the Solar System']
#
# 🔍 Attempting to fetch page: Solar System
# 📄 Page Retrieved: Solar System (Page ID: 26903)
# 🔍 Total chunks to evaluate: 51
# AnswerResult(text='Jupiter', score=0.9914')
# AnswerResult(text='Jupiter', score=0.9765')
# AnswerResult(text='Nine', score=0.6447')
# AnswerResult(text='Ceres', score=0.3391')
# AnswerResult(text='Jupiter', score=0.9570')
# AnswerResult(text='95–5.46 Au)', score=0.2898')
# 🔍 Attempting to fetch page: Ice planet
# 📄 Page Retrieved: Ice planet (Page ID: 31222733)
# 🔍 Total chunks to evaluate: 3
# 🔍 Attempting to fetch page: List of gravitationally rounded objects of the Solar System
# 📄 Page Retrieved: List of gravitationally rounded objects of the Solar System (Page ID: 5828178)
# 🔍 Total chunks to evaluate: 8
# AnswerResult(text='Mercury', score=0.4265')
# AnswerResult(text='Mercury', score=0.2298')
# 🏆 Best answer: Jupiter with score 0.5168
# ✅ Exporting: ['What is the largest planet in the Solar System?', 'Jupiter', 'Jupiter']
#
# ❓ Question: In which year did World War II end?
# Found the following relevant Wikipedia documents: ['World War II', 'German camp brothels in World War II', 'Brazil in World War II']
#
# 🔍 Attempting to fetch page: World War II
# 📄 Page Retrieved: World War II (Page ID: 32927)
# 🔍 Total chunks to evaluate: 67
# AnswerResult(text='1945', score=0.5346')
# AnswerResult(text='1941', score=0.8286')
# AnswerResult(text='1945', score=0.3557')
# AnswerResult(text='1936', score=0.7327')
# AnswerResult(text='1940', score=0.3787')
# AnswerResult(text='1941', score=0.7554')
# AnswerResult(text='1939', score=0.2447')
# AnswerResult(text='1945', score=0.2755')
# AnswerResult(text='1942', score=0.3106')
# 🔍 Attempting to fetch page: German camp brothels in World War II
# 📄 Page Retrieved: German camp brothels in World War II (Page ID: 26483908)
# 🔍 Total chunks to evaluate: 5
# 🔍 Attempting to fetch page: Brazil in World War II
# 📄 Page Retrieved: Brazil in World War II (Page ID: 39872876)
# 🔍 Total chunks to evaluate: 26
# AnswerResult(text='1942', score=0.7894')
# AnswerResult(text='1942', score=0.3846')
# AnswerResult(text='1942', score=0.4931')
# AnswerResult(text='1944', score=0.3504')
# AnswerResult(text='1944', score=0.7684')
# AnswerResult(text='1943', score=0.2781')
# AnswerResult(text='1942', score=0.5550')
# 🏆 Best answer: 1942 with score 0.3117
# ✅ Exporting: ['In which year did World War II end?', '1942', 'World War II ended in 1945.']
#
# ❓ Question: Who painted the Mona Lisa?
# Found the following relevant Wikipedia documents: ['Two–Mona Lisa theory', 'Mona Lisa', 'Mona Lisa (Prado)']
#
# 🔍 Attempting to fetch page: Two–Mona Lisa theory
# 📄 Page Retrieved: Two–Mona Lisa theory (Page ID: 64198205)
# 🔍 Total chunks to evaluate: 13
# AnswerResult(text='Leonardo Da Vinci', score=0.9832')
# AnswerResult(text='Leonardo', score=0.8567')
# AnswerResult(text='Leonardo', score=0.7109')
# AnswerResult(text='Leonardo Da Vinci', score=0.9564')
# AnswerResult(text='Vasari', score=0.2030')
# AnswerResult(text='Pascal Cotte', score=0.8215')
# AnswerResult(text='Lionardo Da Vinci', score=0.8054')
# 🔍 Attempting to fetch page: Mona Lisa
# 📄 Page Retrieved: Mona Lisa (Page ID: 70889)
# 🔍 Total chunks to evaluate: 31
# AnswerResult(text='Leonardo Da Vinci', score=0.9951')
# AnswerResult(text='Leonardo', score=0.2338')
# AnswerResult(text='Vasari', score=0.5830')
# AnswerResult(text='Leonardo', score=0.4622')
# AnswerResult(text='Pascal Cotte', score=0.2693')
# AnswerResult(text='Leonardo', score=0.2548')
# AnswerResult(text='Leonardo Da Vinci', score=0.9238')
# AnswerResult(text='King Francis I', score=0.7181')
# AnswerResult(text='Giuliano De' Medici', score=0.9129')
# AnswerResult(text='Vincenzo Peruggia', score=0.4047')
# AnswerResult(text='Bolivian Ugo Ungaza Villegas', score=0.3013')
# AnswerResult(text='Pascal Cotte', score=0.2659')
# AnswerResult(text='Raphael', score=0.6091')
# AnswerResult(text='Salvador Dalí', score=0.3646')
# AnswerResult(text='Dalí', score=0.5099')
# AnswerResult(text='Leonardo Da Vinci', score=0.2659')
# 🔍 Attempting to fetch page: Mona Lisa (Prado)
# 📄 Page Retrieved: Mona Lisa (Prado) (Page ID: 50783708)
# 🔍 Total chunks to evaluate: 5
# AnswerResult(text='Leonardo Da Vinci', score=0.8180')
# AnswerResult(text='Leonardo Da Vinci', score=0.9617')
# AnswerResult(text='Leonardo Da Vinci', score=0.8939')
# 🏆 Best answer: Leonardo Da Vinci with score 0.3815
# ✅ Exporting: ['Who painted the Mona Lisa?', 'Leonardo Da Vinci', 'The Mona Lisa was painted by the Italian artist Leonardo da Vinci.']
#
# ❓ Question: What is the chemical symbol for gold?
# Found the following relevant Wikipedia documents: ['Chemical symbol', 'Gold', 'Roles of chemical elements']
#
# 🔍 Attempting to fetch page: Chemical symbol
# 📄 Page Retrieved: Chemical symbol (Page ID: 63243)
# 🔍 Total chunks to evaluate: 9
# 🔍 Attempting to fetch page: Gold
# 📄 Page Retrieved: Gold (Page ID: 12240)
# 🔍 Total chunks to evaluate: 57
# AnswerResult(text='Au', score=0.9631')
# AnswerResult(text='Aurous Compounds', score=0.6242')
# AnswerResult(text='V', score=0.7457')
# AnswerResult(text='Quartz', score=0.2882')
# AnswerResult(text='Pure Gold, Clear As Crystal', score=0.5232')
# AnswerResult(text='The Circle With A Point At Its Center (☉)', score=0.2924')
# AnswerResult(text='24K', score=0.4797')
# AnswerResult(text='5.91×1022 Cm−3', score=0.9427')
# AnswerResult(text='Goldwater', score=0.5851')
# AnswerResult(text='Au', score=0.9747')
# 🔍 Attempting to fetch page: Roles of chemical elements
# 📄 Page Retrieved: Roles of chemical elements (Page ID: 35474809)
# 🔍 Total chunks to evaluate: 1
# 🏆 Best answer: Au with score 0.2691
# ✅ Exporting: ['What is the chemical symbol for gold?', 'Au', 'The chemical symbol for gold is Au.']
#
# ❓ Question: Who discovered penicillin?
# Found the following relevant Wikipedia documents: ['Penicillin', 'History of penicillin', 'Alexander Fleming']
#
# 🔍 Attempting to fetch page: Penicillin
# 📄 Page Retrieved: Penicillin (Page ID: 23312)
# 🔍 Total chunks to evaluate: 39
# AnswerResult(text='Alexander Fleming', score=0.9517')
# AnswerResult(text='Alexander Fleming', score=0.9525')
# AnswerResult(text='Alexander Fleming', score=0.4727')
# AnswerResult(text='Alexander Fleming', score=0.9662')
# AnswerResult(text='Alexander Fleming', score=0.7496')
# AnswerResult(text='Howard Florey', score=0.4056')
# AnswerResult(text='Jasper H. Kane', score=0.8338')
# AnswerResult(text='Andrew Jackson Moyer', score=0.9787')
# AnswerResult(text='Beecham Research Laboratories', score=0.4536')
# AnswerResult(text='Penicillium Rubens', score=0.2386')
# AnswerResult(text='Sir Alexander Fleming', score=0.9837')
# 🔍 Attempting to fetch page: History of penicillin
# 📄 Page Retrieved: History of penicillin (Page ID: 4578722)
# 🔍 Total chunks to evaluate: 63
# AnswerResult(text='Howard Florey', score=0.2434')
# AnswerResult(text='Alexander Fleming, Howard Florey And Ernst Chain', score=0.8692')
# AnswerResult(text='Oxford Team', score=0.5452')
# AnswerResult(text='Ernest Duchesne', score=0.5918')
# AnswerResult(text='Charles John Patrick La Touche', score=0.4786')
# AnswerResult(text='La Touche', score=0.4501')
# AnswerResult(text='Frederick Ridley', score=0.7474')
# AnswerResult(text='Abraham And Chain', score=0.6843')
# AnswerResult(text='Florey And Jennings', score=0.3741')
# AnswerResult(text='Roger Reid', score=0.3095')
# AnswerResult(text='Aaron Alston And Charles Aronson', score=0.8218')
# AnswerResult(text='Fletcher', score=0.6705')
# AnswerResult(text='Ethel And Howard Florey', score=0.6296')
# AnswerResult(text='Ethel And Howard Florey', score=0.9577')
# AnswerResult(text='Warren Weaver', score=0.7359')
# AnswerResult(text='Andrew J. Moyer', score=0.2674')
# AnswerResult(text='Kenneth Bryan Raper', score=0.8509')
# AnswerResult(text='Moyer, Coghill And Raper', score=0.7244')
# AnswerResult(text='Coghill', score=0.5352')
# AnswerResult(text='Howard Florey', score=0.8394')
# AnswerResult(text='Maria Brommelhues', score=0.3386')
# AnswerResult(text='Hamao Umezawa', score=0.9633')
# AnswerResult(text='Dorothy Hodgkin', score=0.6376')
# AnswerResult(text='John C. Sheehan', score=0.9455')
# AnswerResult(text='Sir Edward Mellanby', score=0.2211')
# AnswerResult(text='Fleming', score=0.4865')
# AnswerResult(text='Fleming, Florey And Chain', score=0.8698')
# AnswerResult(text='Beecham Research Laboratories', score=0.4739')
# AnswerResult(text='Mary Barber', score=0.9828')
# 🔍 Attempting to fetch page: Alexander Fleming
# 📄 Page Retrieved: Alexander Fleming (Page ID: 1937)
# 🔍 Total chunks to evaluate: 23
# AnswerResult(text='Sir Alexander Fleming', score=0.9925')
# AnswerResult(text='Ernst Chain And Edward Abraham', score=0.9203')
# AnswerResult(text='Fleming', score=0.5860')
# AnswerResult(text='Arthur Dickson Wright', score=0.9450')
# AnswerResult(text='William L. Kissick', score=0.9534')
# AnswerResult(text='Robert D. Coghill And Andrew J. Moyer', score=0.8838')
# AnswerResult(text='Fleming', score=0.3685')
# AnswerResult(text='Macfarlane, Gwyn
# Fleming', score=0.6972')
# AnswerResult(text='Macfarlane, Gwyn
# Fleming', score=0.6793')
# 🏆 Best answer: Alexander Fleming with score 0.1160
# ✅ Exporting: ['Who discovered penicillin?', 'Alexander Fleming', 'Alexander Fleming is credited with the discovery of penicillin in 1928.']
#
# ❓ Question: What is the smallest country in the world by area?
# Found the following relevant Wikipedia documents: ['List of countries and dependencies by area', 'Nolan Chart', 'Microstate']
#
# 🔍 Attempting to fetch page: List of countries and dependencies by area
# 📄 Page Retrieved: List of countries and dependencies by area (Page ID: 3989609)
# 🔍 Total chunks to evaluate: 2
# 🔍 Attempting to fetch page: Nolan Chart
# 📄 Page Retrieved: Nolan Chart (Page ID: 308511)
# 🔍 Total chunks to evaluate: 9
# 🔍 Attempting to fetch page: Microstate
# 📄 Page Retrieved: Microstate (Page ID: 151980)
# 🔍 Total chunks to evaluate: 6
# AnswerResult(text='Vatican City', score=0.9642')
# AnswerResult(text='Vatican City', score=0.8487')
# 🏆 Best answer: Vatican City with score 1.0000
# ✅ Exporting: ['What is the smallest country in the world by area?', 'Vatican City', 'The smallest country in the world by area is Vatican City. It is an independent city-state enclaved within Rome, Italy, and has an area of only 44 hectares (110 acres).']
#
# ❓ Question: What is the currency of Japan?
# Found the following relevant Wikipedia documents: ['Japanese yen', 'Yuan (currency)', 'Euro']
#
# 🔍 Attempting to fetch page: Japanese yen
# 📄 Page Retrieved: Japanese yen (Page ID: 34392)
# 🔍 Total chunks to evaluate: 24
# AnswerResult(text='The Yen', score=0.8331')
# AnswerResult(text='A Fixed Exchange Rate', score=0.4090')
# AnswerResult(text='Yen', score=0.3555')
# AnswerResult(text='Yen', score=0.2066')
# AnswerResult(text='0.75 G Fine Gold', score=0.3004')
# AnswerResult(text='Us$', score=0.8103')
# AnswerResult(text='Yen', score=0.2582')
# AnswerResult(text='Japanese Yen', score=0.5781')
# AnswerResult(text='Japanese Yen', score=0.2790')
# 🔍 Attempting to fetch page: Yuan (currency)
# 📄 Page Retrieved: Yuan (currency) (Page ID: 2279472)
# 🔍 Total chunks to evaluate: 14
# AnswerResult(text='Yen', score=0.9589')
# AnswerResult(text='Yen', score=0.5548')
# 🔍 Attempting to fetch page: Euro
# 📄 Page Retrieved: Euro (Page ID: 9472)
# 🔍 Total chunks to evaluate: 33
# AnswerResult(text='Yen', score=0.9240')
# 🏆 Best answer: Yen with score 0.5073
# ✅ Exporting: ['What is the currency of Japan?', 'Yen', 'The currency of Japan is the Japanese Yen (JPY).']
#
# ❓ Question: Who was the first person to walk on the moon?
# Found the following relevant Wikipedia documents: ['List of Apollo astronauts', 'A Walk on the Moon', 'Moonwalk']
#
# 🔍 Attempting to fetch page: List of Apollo astronauts
# 📄 Page Retrieved: List of Apollo astronauts (Page ID: 129540)
# 🔍 Total chunks to evaluate: 19
# AnswerResult(text='Donald K. "Deke" Slayton', score=0.2739')
# AnswerResult(text='Edward H. White Ii', score=0.8472')
# AnswerResult(text='Neil A. Armstrong', score=0.2921')
# AnswerResult(text='Neil A. Armstrong', score=0.9968')
# AnswerResult(text='Edwin E. "Buzz" Aldrin Jr.', score=0.2167')
# AnswerResult(text='Charles M. Duke Jr.', score=0.2467')
# AnswerResult(text='Alan Shepard', score=0.2171')
# AnswerResult(text='Haise', score=0.3234')
# AnswerResult(text='Alan Shepard', score=0.4634')
# AnswerResult(text='Jim Lovell And Fred Haise', score=0.4776')
# AnswerResult(text='Scott', score=0.3943')
# AnswerResult(text='Neil A. Armstrong', score=0.7182')
# AnswerResult(text='Alan Shepard', score=0.7580')
# 🔍 Attempting to fetch page: A Walk on the Moon
# 📄 Page Retrieved: A Walk on the Moon (Page ID: 692682)
# 🔍 Total chunks to evaluate: 7
# AnswerResult(text='Neil Armstrong', score=0.3080')
# AnswerResult(text='Neil Armstrong', score=0.9563')
# 🔍 Attempting to fetch page: Moonwalk
# 📄 Page Retrieved: Moonwalk (Page ID: 175311)
# 🔍 Total chunks to evaluate: 1
# 🏆 Best answer: Neil A. Armstrong with score 0.2376
# ✅ Exporting: ['Who was the first person to walk on the moon?', 'Neil A. Armstrong', 'Neil Armstrong was the first person to walk on the moon on July 20, 1969 during the Apollo 11 mission.']
#
# ❓ Question: What is the tallest mountain on Earth?
# Found the following relevant Wikipedia documents: ['Mountain', 'List of tallest people', 'List of tallest trees']
#
# 🔍 Attempting to fetch page: Mountain
# 📄 Page Retrieved: Mountain (Page ID: 37754)
# 🔍 Total chunks to evaluate: 16
# AnswerResult(text='Mauna Kea', score=0.6067')
# AnswerResult(text='Mauna Kea', score=0.8709')
# AnswerResult(text='Mount Everest', score=0.9668')
# AnswerResult(text='Mount Everest', score=0.8957')
# AnswerResult(text='Huascarán', score=0.2406')
# 🔍 Attempting to fetch page: List of tallest people
# 📄 Page Retrieved: List of tallest people (Page ID: 11994740)
# 🔍 Total chunks to evaluate: 2
# 🔍 Attempting to fetch page: List of tallest trees
# 📄 Page Retrieved: List of tallest trees (Page ID: 62802048)
# 🔍 Total chunks to evaluate: 3
# 🏆 Best answer: Mount Everest with score 0.4803
# ✅ Exporting: ['What is the tallest mountain on Earth?', 'Mount Everest', 'Mount Everest is the tallest mountain on Earth, with a peak that reaches 29,032 feet (8,848 meters) above sea level.']
#
# ❓ Question: Which element has the atomic number 1?
# Found the following relevant Wikipedia documents: ['Atomic number', 'Atomic mass', 'List of chemical elements']
#
# 🔍 Attempting to fetch page: Atomic number
# 📄 Page Retrieved: Atomic number (Page ID: 673)
# 🔍 Total chunks to evaluate: 11
# AnswerResult(text='Gold', score=0.2257')
# 🔍 Attempting to fetch page: Atomic mass
# 📄 Page Retrieved: Atomic mass (Page ID: 19604151)
# 🔍 Total chunks to evaluate: 14
# AnswerResult(text='Carbon-12', score=0.4010')
# AnswerResult(text='Chlorine', score=0.9125')
# 🔍 Attempting to fetch page: List of chemical elements
# 📄 Page Retrieved: List of chemical elements (Page ID: 2152181)
# 🔍 Total chunks to evaluate: 1
# 🏆 Best answer: Chlorine with score 0.4756
# ✅ Exporting: ['Which element has the atomic number 1?', 'Chlorine', 'Hydrogen']
#
# ❓ Question: What is the largest mammal on Earth?
# Found the following relevant Wikipedia documents: ['Largest organisms', 'List of largest fish', 'Earth']
#
# 🔍 Attempting to fetch page: Largest organisms
# 📄 Page Retrieved: Largest organisms (Page ID: 20598041)
# 🔍 Total chunks to evaluate: 7
# AnswerResult(text='African Bush Elephant', score=0.3393')
# 🔍 Attempting to fetch page: List of largest fish
# 📄 Page Retrieved: List of largest fish (Page ID: 41365652)
# 🔍 Total chunks to evaluate: 47
# AnswerResult(text='Sea Lamprey', score=0.8179')
# AnswerResult(text='Nursehound', score=0.5685')
# AnswerResult(text='Longnose Lancetfish', score=0.3416')
# AnswerResult(text='Chinese Seerfish', score=0.2365')
# AnswerResult(text='Congo Bichir', score=0.2474')
# AnswerResult(text='Lingcod', score=0.2685')
# 🔍 Attempting to fetch page: Earth
# 📄 Page Retrieved: Earth (Page ID: 9228)
# 🔍 Total chunks to evaluate: 50
# AnswerResult(text='Plants And Animals', score=0.4352')
# 🏆 Best answer: Sea Lamprey with score 0.1851
# ✅ Exporting: ['What is the largest mammal on Earth?', 'Sea Lamprey', 'The largest mammal on Earth is the blue whale (Balaenoptera musculus).']
#
# ❓ Question: Who developed the theory of relativity?
# Found the following relevant Wikipedia documents: ['General relativity', 'Special relativity', 'Principle of relativity']
#
# 🔍 Attempting to fetch page: General relativity
# 📄 Page Retrieved: General relativity (Page ID: 12024)
# 🔍 Total chunks to evaluate: 61
# AnswerResult(text='Albert Einstein', score=0.8019')
# AnswerResult(text='Marcel Grossmann', score=0.3926')
# AnswerResult(text='Eötvös', score=0.2029')
# AnswerResult(text='Einstein', score=0.8980')
# AnswerResult(text='Einstein', score=0.7435')
# AnswerResult(text='Urbain Le Verrier', score=0.3106')
# 🔍 Attempting to fetch page: Special relativity
# 📄 Page Retrieved: Special relativity (Page ID: 26962)
# 🔍 Total chunks to evaluate: 136
# AnswerResult(text='Galileo', score=0.8949')
# AnswerResult(text='Galileo', score=0.6476')
# AnswerResult(text='Paul Langevin', score=0.9341')
# AnswerResult(text='Einstein', score=0.8036')
# AnswerResult(text='Bell', score=0.9372')
# AnswerResult(text='Lawrence Sklar', score=0.6581')
# 🔍 Attempting to fetch page: Principle of relativity
# 📄 Page Retrieved: Principle of relativity (Page ID: 74327)
# 🔍 Total chunks to evaluate: 7
# AnswerResult(text='Einstein', score=0.7593')
# 🏆 Best answer: Einstein with score 0.3355
# ✅ Exporting: ['Who developed the theory of relativity?', 'Einstein', 'The theory of relativity was developed by Albert Einstein.']
#
# ❓ Question: What is the capital city of Canada?
# Found the following relevant Wikipedia documents: ['Ottawa', 'Quebec City', 'Toronto']
#
# 🔍 Attempting to fetch page: Ottawa
# 📄 Page Retrieved: Ottawa (Page ID: 22219)
# 🔍 Total chunks to evaluate: 44
# AnswerResult(text='Ottawa', score=0.9961')
# AnswerResult(text='Ottawa', score=0.9232')
# AnswerResult(text='Kingston', score=0.2238')
# AnswerResult(text='Ottawa', score=0.9815')
# AnswerResult(text='Toronto', score=0.3420')
# AnswerResult(text='Ottawa', score=0.5956')
# AnswerResult(text='Ottawa', score=0.8975')
# AnswerResult(text='Ottawa', score=0.9803')
# AnswerResult(text='Ottawa', score=0.8511')
# AnswerResult(text='Ottawa', score=0.5844')
# AnswerResult(text='Ottawa', score=0.4931')
# AnswerResult(text='Ottawa-Gatineau', score=0.5692')
# AnswerResult(text='Ottawa', score=0.7941')
# AnswerResult(text='Ottawa', score=0.9244')
# AnswerResult(text='Ottawa', score=0.8667')
# AnswerResult(text='Ottawa', score=0.9729')
# AnswerResult(text='Ottawa', score=0.4792')
# AnswerResult(text='Ottawa', score=0.2338')
# AnswerResult(text='Ottawa', score=0.2980')
# AnswerResult(text='Ottawa', score=0.3191')
# 🔍 Attempting to fetch page: Quebec City
# 📄 Page Retrieved: Quebec City (Page ID: 100727)
# 🔍 Total chunks to evaluate: 34
# AnswerResult(text='Quebec', score=0.3531')
# AnswerResult(text='Kingston, Montreal, Toronto, Ottawa And Quebec City', score=0.4872')
# AnswerResult(text='Quebec', score=0.4893')
# AnswerResult(text='Quebec City', score=0.4224')
# 🔍 Attempting to fetch page: Toronto
# 📄 Page Retrieved: Toronto (Page ID: 64646)
# 🔍 Total chunks to evaluate: 68
# AnswerResult(text='Toronto', score=0.9682')
# AnswerResult(text='Toronto', score=0.2193')
# AnswerResult(text='Newark', score=0.4168')
# AnswerResult(text='Newark', score=0.5835')
# AnswerResult(text='Quebec', score=0.3517')
# AnswerResult(text='Ottawa, Ontario', score=0.8487')
# AnswerResult(text='Toronto', score=0.3855')
# AnswerResult(text='Montreal, Quebec', score=0.7718')
# AnswerResult(text='Montreal', score=0.9928')
# AnswerResult(text='Toronto', score=0.6008')
# AnswerResult(text='Toronto', score=0.6778')
# AnswerResult(text='Miami, Florida', score=0.3629')
# AnswerResult(text='Toronto', score=0.9289')
# AnswerResult(text='Quebec City–Windsor', score=0.4765')
# AnswerResult(text='Toronto', score=0.4140')
# AnswerResult(text='Toronto', score=0.7168')
# AnswerResult(text='Scarborough', score=0.9144')
# AnswerResult(text='Mississauga', score=0.6435')
# AnswerResult(text='Vancouver', score=0.2134')
# AnswerResult(text='Toronto', score=0.9209')
# AnswerResult(text='Vancouver', score=0.5719')
# AnswerResult(text='Los Angeles', score=0.6345')
# AnswerResult(text='Montreal', score=0.7044')
# AnswerResult(text='Downtown', score=0.2155')
# AnswerResult(text='Vancouver', score=0.9952')
# 🏆 Best answer: Ottawa with score 0.3802
# ✅ Exporting: ['What is the capital city of Canada?', 'Ottawa', 'The capital city of Canada is Ottawa.']
#
# ❓ Question: What is the longest river in the world?
# Found the following relevant Wikipedia documents: ['List of river systems by length', 'Amazon River', 'List of longest films']
#
# 🔍 Attempting to fetch page: List of river systems by length
# 📄 Page Retrieved: List of river systems by length (Page ID: 922586)
# 🔍 Total chunks to evaluate: 5
# AnswerResult(text='The Nile Or The Amazon', score=0.3086')
# AnswerResult(text='Amazon Or The Nile', score=0.5927')
# AnswerResult(text='Selenga River', score=0.3005')
# 🔍 Attempting to fetch page: Amazon River
# 📄 Page Retrieved: Amazon River (Page ID: 1701)
# 🔍 Total chunks to evaluate: 40
# AnswerResult(text='The Amazon River', score=0.5774')
# AnswerResult(text='Marañón', score=0.3920')
# AnswerResult(text='Rio Negro', score=0.5329')
# AnswerResult(text='Mantaro', score=0.3930')
# AnswerResult(text='Mantaro', score=0.2498')
# AnswerResult(text='Amazon River', score=0.2612')
# AnswerResult(text='Marajó', score=0.8083')
# AnswerResult(text='The Amazon Basin', score=0.3108')
# AnswerResult(text='Amazon Basin', score=0.5487')
# AnswerResult(text='Casiquiare', score=0.2838')
# AnswerResult(text='The Casiquiare', score=0.5577')
# AnswerResult(text='Ucayali River', score=0.5436')
# 🔍 Attempting to fetch page: List of longest films
# 📄 Page Retrieved: List of longest films (Page ID: 484039)
# 🔍 Total chunks to evaluate: 1
# 🏆 Best answer: Mantaro with score 0.1167
# ✅ Exporting: ['What is the longest river in the world?', 'Mantaro', 'The longest river in the world is the Nile River, with a length of approximately 4,135 miles (6,650 kilometers).']
#
# ❓ Question: Who invented the telephone?
# Found the following relevant Wikipedia documents: ['Telephone', 'The Telephone Cases', 'Antonio Meucci']
#
# 🔍 Attempting to fetch page: Telephone
# 📄 Page Retrieved: Telephone (Page ID: 30003)
# 🔍 Total chunks to evaluate: 26
# AnswerResult(text='Alexander Graham Bell', score=0.9865')
# AnswerResult(text='Johann Philipp Reis', score=0.3765')
# AnswerResult(text='Captain John Taylor', score=0.9945')
# AnswerResult(text='Bell', score=0.2922')
# AnswerResult(text='Johann Philipp Reis', score=0.2844')
# AnswerResult(text='Antonio Meucci', score=0.6581')
# AnswerResult(text='Thomas Edison', score=0.4488')
# AnswerResult(text='Edison', score=0.4820')
# AnswerResult(text='Bell', score=0.7777')
# AnswerResult(text='Elisha Gray – Alexander Bell', score=0.8656')
# AnswerResult(text='Thomas Edison', score=0.7263')
# 🔍 Attempting to fetch page: The Telephone Cases
# 📄 Page Retrieved: The Telephone Cases (Page ID: 25262973)
# 🔍 Total chunks to evaluate: 5
# AnswerResult(text='Alexander Graham Bell', score=0.9691')
# AnswerResult(text='Daniel Drawbaugh', score=0.9153')
# 🔍 Attempting to fetch page: Antonio Meucci
# 📄 Page Retrieved: Antonio Meucci (Page ID: 364887)
# 🔍 Total chunks to evaluate: 31
# AnswerResult(text='Antonio Santi Giuseppe Meucci', score=0.8054')
# AnswerResult(text='Amatis Meucci', score=0.3769')
# AnswerResult(text='Samuel F. B. Morse', score=0.8063')
# AnswerResult(text='Nestore Corradi', score=0.4939')
# AnswerResult(text='Meucci', score=0.5296')
# AnswerResult(text='William E. Ryder', score=0.4295')
# AnswerResult(text='Robert V. Bruce', score=0.4248')
# AnswerResult(text='Bell', score=0.5307')
# AnswerResult(text='Bill Carroll', score=0.8210')
# AnswerResult(text='Meucci', score=0.5662')
# AnswerResult(text='Antonio Meucci', score=0.7364')
# AnswerResult(text='Antonio Meucci', score=0.9961')
# AnswerResult(text='Bell', score=0.7530')
# AnswerResult(text='Antonio Meucci', score=0.2057')
# AnswerResult(text='Antonio Meucci', score=0.9624')
# AnswerResult(text='Meucci', score=0.2705')
# AnswerResult(text='Schiavo, Giovanni E., Antonio Meucci', score=0.5570')
# AnswerResult(text='Dossena Tiziano Thomas, Meucci', score=0.4655')
# AnswerResult(text='Fenster Julie M.', score=0.2757')
# 🏆 Best answer: Antonio Meucci with score 0.1728
# ✅ Exporting: ['Who invented the telephone?', 'Antonio Meucci', 'The telephone was invented by Alexander Graham Bell in 1876.']
#
# ❓ Question: What is the official language of Brazil?
# Found the following relevant Wikipedia documents: ['Languages of Brazil', 'List of official languages by country and territory', 'Official languages of the United Nations']
#
# 🔍 Attempting to fetch page: Languages of Brazil
# 📄 Page Retrieved: Languages of Brazil (Page ID: 5272547)
# 🔍 Total chunks to evaluate: 25
# AnswerResult(text='Portuguese', score=0.9892')
# AnswerResult(text='Brazilian Sign Language', score=0.3541')
# AnswerResult(text='Língua Geral', score=0.7283')
# AnswerResult(text='Portuguese', score=0.7194')
# AnswerResult(text='Brazilian Portuguese
# Brazilian Portuguese', score=0.6223')
# AnswerResult(text='Portuguese', score=0.8689')
# AnswerResult(text='Portuguese', score=0.9622')
# AnswerResult(text='Spanish', score=0.5453')
# AnswerResult(text='Spanish', score=0.4261')
# 🔍 Attempting to fetch page: List of official languages by country and territory
# 📄 Page Retrieved: List of official languages by country and territory (Page ID: 320521)
# 🔍 Total chunks to evaluate: 1
# 🔍 Attempting to fetch page: Official languages of the United Nations
# 📄 Page Retrieved: Official languages of the United Nations (Page ID: 25948712)
# 🔍 Total chunks to evaluate: 16
# 🏆 Best answer: Portuguese with score 0.5307
# ✅ Exporting: ['What is the official language of Brazil?', 'Portuguese', 'The official language of Brazil is Portuguese.']
#
# ❓ Question: Which country hosted the 2016 Summer Olympics?
# Found the following relevant Wikipedia documents: ['Summer Olympic Games', 'List of Olympic Games host cities', '2028 Summer Olympics']
#
# 🔍 Attempting to fetch page: Summer Olympic Games
# 📄 Page Retrieved: Summer Olympic Games (Page ID: 27566)
# 🔍 Total chunks to evaluate: 27
# AnswerResult(text='Brazil', score=0.9884')
# AnswerResult(text='Brazil', score=0.9926')
# AnswerResult(text='Brazil', score=0.2182')
# AnswerResult(text='Brazil', score=0.6689')
# AnswerResult(text='Berlin', score=0.8766')
# AnswerResult(text='Czechoslovakia', score=0.2942')
# AnswerResult(text='Brazil', score=0.6889')
# AnswerResult(text='Australia', score=0.5572')
# 🔍 Attempting to fetch page: List of Olympic Games host cities
# 📄 Page Retrieved: List of Olympic Games host cities (Page ID: 11015817)
# 🔍 Total chunks to evaluate: 5
# 🔍 Attempting to fetch page: 2028 Summer Olympics
# 📄 Page Retrieved: 2028 Summer Olympics (Page ID: 12695048)
# 🔍 Total chunks to evaluate: 20
# AnswerResult(text='Arcadia', score=0.5999')
# AnswerResult(text='United States', score=0.2345')
# 🏆 Best answer: Brazil with score 0.5521
# ✅ Exporting: ['Which country hosted the 2016 Summer Olympics?', 'Brazil', 'The 2016 Summer Olympics were hosted by Brazil, with most events taking place in Rio de Janeiro.']
#
# ❓ Question: What is the fastest land animal?
# Found the following relevant Wikipedia documents: ['Largest and heaviest animals', 'Paratarsotomus macropalpis', 'History of life']
#
# 🔍 Attempting to fetch page: Largest and heaviest animals
# 📄 Page Retrieved: Largest and heaviest animals (Page ID: 34477913)
# 🔍 Total chunks to evaluate: 58
# 🔍 Attempting to fetch page: Paratarsotomus macropalpis
# 📄 Page Retrieved: Paratarsotomus macropalpis (Page ID: 42607748)
# 🔍 Total chunks to evaluate: 3
# AnswerResult(text='The Cheetah', score=0.5579')
# 🔍 Attempting to fetch page: History of life
# 📄 Page Retrieved: History of life (Page ID: 12305127)
# 🔍 Total chunks to evaluate: 56
# 🏆 Best answer: The Cheetah with score 1.0000
# ✅ Exporting: ['What is the fastest land animal?', 'The Cheetah', 'The fastest land animal is the cheetah, which can reach speeds of up to 75 miles per hour (120 km/h) in short bursts covering distances up to 500 meters.']
#
# ❓ Question: Who is known as the father of modern physics?
# Found the following relevant Wikipedia documents: ['Physics', 'History of physics', 'List of people considered father or mother of a field']
#
# 🔍 Attempting to fetch page: Physics
# 📄 Page Retrieved: Physics (Page ID: 22939)
# 🔍 Total chunks to evaluate: 28
# 🔍 Attempting to fetch page: History of physics
# 📄 Page Retrieved: History of physics (Page ID: 13758)
# 🔍 Total chunks to evaluate: 67
# AnswerResult(text='Thales Of Miletus', score=0.6093')
# AnswerResult(text='Thales Of Miletus', score=0.7512')
# AnswerResult(text='Galileo', score=0.9394')
# AnswerResult(text='Max Planck', score=0.4170')
# 🔍 Attempting to fetch page: List of people considered father or mother of a field
# 📄 Page Retrieved: List of people considered father or mother of a field (Page ID: 12819734)
# 🔍 Total chunks to evaluate: 1
# 🏆 Best answer: Thales Of Miletus with score 0.4927
# ✅ Exporting: ['Who is known as the father of modern physics?', 'Thales Of Miletus', 'Albert Einstein is often referred to as the father of modern physics.']
#
# ❓ Question: Which continent is the Sahara Desert located in?
# Found the following relevant Wikipedia documents: ['Sahara desert (ecoregion)', 'Sahara', 'Africa']
#
# 🔍 Attempting to fetch page: Sahara desert (ecoregion)
# 📄 Page Retrieved: Sahara desert (ecoregion) (Page ID: 27068)
# 🔍 Total chunks to evaluate: 5
# AnswerResult(text='African Continent', score=0.4069')
# AnswerResult(text='Sahel', score=0.4988')
# 🔍 Attempting to fetch page: Sahara
# 📄 Page Retrieved: Sahara (Page ID: 325363)
# 🔍 Total chunks to evaluate: 47
# AnswerResult(text='North Africa', score=0.7647')
# AnswerResult(text='Northern Africa', score=0.4574')
# AnswerResult(text='North-African', score=0.3343')
# AnswerResult(text='Sahel And Southern', score=0.5196')
# AnswerResult(text='Mali', score=0.2605')
# AnswerResult(text='Southern', score=0.2280')
# AnswerResult(text='Sahel', score=0.2565')
# AnswerResult(text='Eastern Sahara', score=0.2748')
# AnswerResult(text='Eastern', score=0.6094')
# AnswerResult(text='Southern Sahara', score=0.2658')
# AnswerResult(text='Atlas Mountains', score=0.3014')
# AnswerResult(text='Northern Maghreb And Cyrenaica', score=0.2221')
# AnswerResult(text='Arabian', score=0.6236')
# AnswerResult(text='West Africa', score=0.3488')
# 🔍 Attempting to fetch page: Africa
# 📄 Page Retrieved: Africa (Page ID: 5334607)
# 🔍 Total chunks to evaluate: 62
# AnswerResult(text='Northern West Africa', score=0.3827')
# 🏆 Best answer: Sahel with score 0.1148
# ✅ Exporting: ['Which continent is the Sahara Desert located in?', 'Sahel', 'Africa']
#
# ❓ Question: Who was the first President of the United States?
# Found the following relevant Wikipedia documents: ['List of presidents of the United States', 'President of the United States', 'List of presidents of the United States by time in office']
#
# 🔍 Attempting to fetch page: List of presidents of the United States
# 📄 Page Retrieved: List of presidents of the United States (Page ID: 19908980)
# 🔍 Total chunks to evaluate: 2
# AnswerResult(text='George Washington', score=0.9900')
# 🔍 Attempting to fetch page: President of the United States
# 📄 Page Retrieved: President of the United States (Page ID: 24113)
# 🔍 Total chunks to evaluate: 52
# AnswerResult(text='George Washington', score=0.9933')
# AnswerResult(text='George Washington', score=0.9941')
# AnswerResult(text='Grover Cleveland', score=0.2879')
# AnswerResult(text='Grover Cleveland', score=0.3989')
# AnswerResult(text='Franklin D. Roosevelt', score=0.9828')
# AnswerResult(text='John Adams', score=0.6180')
# AnswerResult(text='George Washington', score=0.9908')
# AnswerResult(text='Thomas Jefferson', score=0.3153')
# AnswerResult(text='George Washington', score=0.9930')
# AnswerResult(text='Theodore Roosevelt', score=0.6682')
# AnswerResult(text='George W. Bush', score=0.6045')
# AnswerResult(text='Herbert Hoover', score=0.7093')
# 🔍 Attempting to fetch page: List of presidents of the United States by time in office
# 📄 Page Retrieved: List of presidents of the United States by time in office (Page ID: 1038417)
# 🔍 Total chunks to evaluate: 2
# 🏆 Best answer: George Washington with score 0.4813
# ✅ Exporting: ['Who was the first President of the United States?', 'George Washington', 'George Washington']
#
# ❓ Question: What is the main ingredient in guacamole?
# Found the following relevant Wikipedia documents: ['Guacamole', 'Mole (sauce)', 'Chimichanga']
#
# 🔍 Attempting to fetch page: Guacamole
# 📄 Page Retrieved: Guacamole (Page ID: 484865)
# 🔍 Total chunks to evaluate: 5
# AnswerResult(text='Avocado', score=0.9642')
# AnswerResult(text='Nutrients', score=0.4100')
# AnswerResult(text='Avocado', score=0.6552')
# 🔍 Attempting to fetch page: Mole (sauce)
# 📄 Page Retrieved: Mole (sauce) (Page ID: 26496776)
# 🔍 Total chunks to evaluate: 17
# AnswerResult(text='Avocado', score=0.6733')
# AnswerResult(text='Sugar And Cocoa', score=0.6421')
# AnswerResult(text='Corn, Fava Bean', score=0.2436')
# AnswerResult(text='Avocado Sauce', score=0.2099')
# AnswerResult(text='Mole', score=0.3756')
# 🔍 Attempting to fetch page: Chimichanga
# 📄 Page Retrieved: Chimichanga (Page ID: 1548665)
# 🔍 Total chunks to evaluate: 4
# 🏆 Best answer: Avocado with score 0.4689
# ✅ Exporting: ['What is the main ingredient in guacamole?', 'Avocado', 'The main ingredient in guacamole is avocado.']
#
# ❓ Question: What is the largest ocean on Earth?
# Found the following relevant Wikipedia documents: ['Ocean', 'Earth', 'Pacific Ocean']
#
# 🔍 Attempting to fetch page: Ocean
# 📄 Page Retrieved: Ocean (Page ID: 18842359)
# 🔍 Total chunks to evaluate: 48
# 🔍 Attempting to fetch page: Earth
# 📄 Page Retrieved: Earth (Page ID: 9228)
# 🔍 Total chunks to evaluate: 50
# AnswerResult(text='Arctic Ocean', score=0.2834')
# 🔍 Attempting to fetch page: Pacific Ocean
# 📄 Page Retrieved: Pacific Ocean (Page ID: 23070)
# 🔍 Total chunks to evaluate: 25
# AnswerResult(text='The Pacific Ocean', score=0.5001')
# AnswerResult(text='Indian Ocean', score=0.4255')
# AnswerResult(text='Pacific Ocean', score=0.2926')
# 🏆 Best answer: The Pacific Ocean with score 0.2820
# ✅ Exporting: ['What is the largest ocean on Earth?', 'The Pacific Ocean', 'The largest ocean on Earth is the Pacific Ocean.']
#
# ❓ Question: Who directed the movie 'Titanic'?
# Found the following relevant Wikipedia documents: ['Titanic (1997 film)', 'Titanic II (film)', 'Titanic 666']
#
# 🔍 Attempting to fetch page: Titanic (1997 film)
# 📄 Page Retrieved: Titanic (1997 film) (Page ID: 52371)
# 🔍 Total chunks to evaluate: 77
# AnswerResult(text='James Cameron', score=0.8107')
# AnswerResult(text='Brock Lovett', score=0.6842')
# AnswerResult(text='Jack Dawson', score=0.3263')
# AnswerResult(text='Leonardo Dicaprio', score=0.3172')
# AnswerResult(text='Mali Finn', score=0.9526')
# AnswerResult(text='Billy Zane', score=0.4134')
# AnswerResult(text='Bill Paxton', score=0.3107')
# AnswerResult(text='Jonathan Hyde', score=0.4896')
# AnswerResult(text='Bernard Fox', score=0.5149')
# AnswerResult(text='Kevin De La Noy', score=0.9610')
# AnswerResult(text='Martin Jarvis', score=0.4305')
# AnswerResult(text='Scott G. Anderson', score=0.2417')
# AnswerResult(text='Terry Forrestal', score=0.3275')
# AnswerResult(text='James Cameron', score=0.3834')
# AnswerResult(text='Peter Chernin', score=0.2692')
# AnswerResult(text='Brock Lovett', score=0.9631')
# AnswerResult(text='Cameron', score=0.2290')
# AnswerResult(text='Peter Lamont', score=0.4714')
# AnswerResult(text='Jay Kantola', score=0.3456')
# AnswerResult(text='Cameron', score=0.3732')
# AnswerResult(text='Bill Paxton', score=0.7598')
# AnswerResult(text='Lewis Abernathy', score=0.6900')
# AnswerResult(text='Jon Landau', score=0.5040')
# AnswerResult(text='Rob Legato', score=0.8505')
# AnswerResult(text='Cameron', score=0.4475')
# AnswerResult(text='James Horner', score=0.6072')
# AnswerResult(text='Harrison Ford', score=0.8017')
# AnswerResult(text='Cameron', score=0.2419')
# AnswerResult(text='James Cameron', score=0.7317')
# AnswerResult(text='James Cameron', score=0.9327')
# AnswerResult(text='Robert Altman', score=0.7816')
# AnswerResult(text='Richard Davenport-Hines', score=0.2638')
# AnswerResult(text='James Cameron', score=0.5138')
# AnswerResult(text='Meagan Burrows', score=0.6023')
# AnswerResult(text='James Cameron', score=0.8767')
# AnswerResult(text='Neil Degrasse Tyson', score=0.6400')
# 🔍 Attempting to fetch page: Titanic II (film)
# 📄 Page Retrieved: Titanic II (film) (Page ID: 27405104)
# 🔍 Total chunks to evaluate: 6
# AnswerResult(text='Shane Van Dyke', score=0.9718')
# AnswerResult(text='Josh Roman', score=0.4947')
# AnswerResult(text='James Cameron', score=0.6870')
# 🔍 Attempting to fetch page: Titanic 666
# 📄 Page Retrieved: Titanic 666 (Page ID: 70606781)
# 🔍 Total chunks to evaluate: 6
# AnswerResult(text='Nick Lyon', score=0.9982')
# 🏆 Best answer: James Cameron with score 0.1956
# ✅ Exporting: ["Who directed the movie 'Titanic'?", 'James Cameron', 'James Cameron directed the movie "Titanic".']
#
# ❓ Question: What is the boiling point of water at sea level in Celsius?
# Found the following relevant Wikipedia documents: ['Boiling water reactor', 'Celsius', 'Cryogenics']
#
# 🔍 Attempting to fetch page: Boiling water reactor
# 📄 Page Retrieved: Boiling water reactor (Page ID: 143351)
# 🔍 Total chunks to evaluate: 39
# AnswerResult(text='1,230 °C)', score=0.2620')
# 🔍 Attempting to fetch page: Celsius
# 📄 Page Retrieved: Celsius (Page ID: 19593040)
# 🔍 Total chunks to evaluate: 12
# AnswerResult(text='1 Atm Pressure', score=0.4033')
# AnswerResult(text='100', score=0.6580')
# 🔍 Attempting to fetch page: Cryogenics
# 📄 Page Retrieved: Cryogenics (Page ID: 7176)
# 🔍 Total chunks to evaluate: 10
# 🏆 Best answer: 100 with score 0.4085
# ✅ Exporting: ['What is the boiling point of water at sea level in Celsius?', '100', 'The boiling point of water at sea level is 100 degrees Celsius.']
#
# ❓ Question: What country is known as the Land of the Rising Sun?
# Found the following relevant Wikipedia documents: ['Rising Sun Flag', 'Levant', 'Netherlands']
#
# 🔍 Attempting to fetch page: Rising Sun Flag
# 📄 Page Retrieved: Rising Sun Flag (Page ID: 11535807)
# 🔍 Total chunks to evaluate: 15
# AnswerResult(text='Japan', score=0.7815')
# AnswerResult(text='Japan', score=0.9492')
# AnswerResult(text='Japan', score=0.9718')
# AnswerResult(text='South Korea', score=0.2445')
# 🔍 Attempting to fetch page: Levant
# 📄 Page Retrieved: Levant (Page ID: 18138)
# 🔍 Total chunks to evaluate: 12
# AnswerResult(text='Italy', score=0.7334')
# 🔍 Attempting to fetch page: Netherlands
# 📄 Page Retrieved: Netherlands (Page ID: 21148)
# 🔍 Total chunks to evaluate: 74
# AnswerResult(text='Dutch Republic', score=0.2328')
# AnswerResult(text='The Netherlands Is One Of The Most Secular Countries Of Europe', score=0.3762')
# 🏆 Best answer: Japan with score 0.5494
# ✅ Exporting: ['What country is known as the Land of the Rising Sun?', 'Japan', 'Japan']
#
# ❓ Question: Who wrote 'To Kill a Mockingbird'?
# Found the following relevant Wikipedia documents: ['List of To Kill a Mockingbird characters', 'To Kill a Mockingbird (film)', 'To Kill a Mockingbird']
#
# 🔍 Attempting to fetch page: List of To Kill a Mockingbird characters
# 📄 Page Retrieved: List of To Kill a Mockingbird characters (Page ID: 8355369)
# 🔍 Total chunks to evaluate: 30
# AnswerResult(text='Harper Lee', score=0.9779')
# AnswerResult(text='Jean Louise "Scout" Finch', score=0.2697')
# AnswerResult(text='Phillip Alford', score=0.2100')
# AnswerResult(text='Truman Capote', score=0.9414')
# AnswerResult(text='Miss Maudie', score=0.9720')
# AnswerResult(text='Atticus', score=0.3494')
# 🔍 Attempting to fetch page: To Kill a Mockingbird (film)
# 📄 Page Retrieved: To Kill a Mockingbird (film) (Page ID: 4607980)
# 🔍 Total chunks to evaluate: 14
# AnswerResult(text='Harper Lee', score=0.4530')
# AnswerResult(text='Atticus', score=0.2981')
# AnswerResult(text='Bob Ewell', score=0.4076')
# AnswerResult(text='Harper Lee', score=0.4714')
# AnswerResult(text='Harper Lee', score=0.7034')
# AnswerResult(text='Horton Foote', score=0.2408')
# AnswerResult(text='Elmer Bernstein', score=0.9548')
# 🔍 Attempting to fetch page: To Kill a Mockingbird
# 📄 Page Retrieved: To Kill a Mockingbird (Page ID: 73408)
# 🔍 Total chunks to evaluate: 52
# AnswerResult(text='Harper Lee', score=0.9953')
# AnswerResult(text='Mary Mcdonough Murphy', score=0.9529')
# AnswerResult(text='Truman Capote', score=0.7297')
# AnswerResult(text='Therese Von Hohoff Torrey', score=0.7235')
# AnswerResult(text='Amasa Coleman Lee', score=0.4549')
# AnswerResult(text='Walter Lett', score=0.9353')
# AnswerResult(text='Jacqueline Tavernier-Courbin', score=0.5455')
# AnswerResult(text='Tavernier-Courbin', score=0.5421')
# AnswerResult(text='Boo Radley', score=0.7150')
# AnswerResult(text='Don Noble', score=0.9612')
# AnswerResult(text='Harper Lee', score=0.7983')
# AnswerResult(text='Harding Lemay', score=0.3254')
# AnswerResult(text='Patrick Chura', score=0.2359')
# AnswerResult(text='Charles J. Shields', score=0.9385')
# AnswerResult(text='Charles J. Shields', score=0.9775')
# AnswerResult(text='Claudia Durst Johnson', score=0.7424')
# AnswerResult(text='Edwin Bruell', score=0.9878')
# AnswerResult(text='Edwin Bruell', score=0.9919')
# AnswerResult(text='Flannery O'Connor', score=0.9398')
# AnswerResult(text='Allen Barra', score=0.4465')
# AnswerResult(text='Akin Ajayi', score=0.7172')
# AnswerResult(text='Harper Lee', score=0.3005')
# AnswerResult(text='Diane Mcwhorter', score=0.9617')
# AnswerResult(text='James Mcbride', score=0.7613')
# AnswerResult(text='Richard M. Daley', score=0.9417')
# AnswerResult(text='Andrew Nurnberg', score=0.5453')
# AnswerResult(text='Horton Foote', score=0.8186')
# AnswerResult(text='Albert Murray', score=0.8085')
# AnswerResult(text='Albert Murray', score=0.3677')
# AnswerResult(text='Harper Lee', score=0.9888')
# 🏆 Best answer: Harper Lee with score 0.1907
# ✅ Exporting: ["Who wrote 'To Kill a Mockingbird'?", 'Harper Lee', 'Harper Lee']
#
# ❓ Question: What is the hardest natural substance on Earth?
# Found the following relevant Wikipedia documents: ['Natural History (Pliny)', 'Carbon', 'Features of the Marvel Cinematic Universe']
#
# 🔍 Attempting to fetch page: Natural History (Pliny)
# 📄 Page Retrieved: Natural History (Pliny) (Page ID: 74215)
# 🔍 Total chunks to evaluate: 39
# AnswerResult(text='Steel', score=0.5624')
# AnswerResult(text='Gangadia Or Quartzite', score=0.7108')
# AnswerResult(text='Gangadia Or Quartzite', score=0.4929')
# 🔍 Attempting to fetch page: Carbon
# 📄 Page Retrieved: Carbon (Page ID: 5299)
# 🔍 Total chunks to evaluate: 39
# AnswerResult(text='Diamond', score=0.8882')
# AnswerResult(text='Diamond', score=0.9355')
# 🔍 Attempting to fetch page: Features of the Marvel Cinematic Universe
# 📄 Page Retrieved: Features of the Marvel Cinematic Universe (Page ID: 66902704)
# 🔍 Total chunks to evaluate: 138
# AnswerResult(text='Molten Core', score=0.2721')
# 🏆 Best answer: Diamond with score 0.4249
# ✅ Exporting: ['What is the hardest natural substance on Earth?', 'Diamond', 'Diamond is the hardest natural substance on Earth.']
#
# ❓ Question: Who is the author of 'Harry Potter'?
# Found the following relevant Wikipedia documents: ['Harry Potter (character)', 'Harry Potter (film series)', 'Harry Potter']
#
# 🔍 Attempting to fetch page: Harry Potter (character)
# 📄 Page Retrieved: Harry Potter (character) (Page ID: 727836)
# 🔍 Total chunks to evaluate: 27
# AnswerResult(text='J. K. Rowling', score=0.9672')
# AnswerResult(text='Jack Thorne', score=0.6463')
# AnswerResult(text='James And Lily Potter', score=0.2314')
# AnswerResult(text='James Potter', score=0.2230')
# AnswerResult(text='J.K. Rowling', score=0.8273')
# AnswerResult(text='Michael Gerber', score=0.5976')
# 🔍 Attempting to fetch page: Harry Potter (film series)
# 📄 Page Retrieved: Harry Potter (film series) (Page ID: 7629286)
# 🔍 Total chunks to evaluate: 38
# AnswerResult(text='J. K. Rowling', score=0.9825')
# AnswerResult(text='David Heyman', score=0.4292')
# AnswerResult(text='J. K. Rowling', score=0.9646')
# AnswerResult(text='Stuart Craig', score=0.7573')
# AnswerResult(text='J.K. Rowling', score=0.6486')
# AnswerResult(text='J. K. Rowling', score=0.8727')
# AnswerResult(text='J. K. Rowling', score=0.7862')
# AnswerResult(text='J.K. Rowling', score=0.2980')
# 🔍 Attempting to fetch page: Harry Potter
# 📄 Page Retrieved: Harry Potter (Page ID: 2387806)
# 🔍 Total chunks to evaluate: 55
# AnswerResult(text='J. K. Rowling', score=0.9766')
# AnswerResult(text='Rowling', score=0.8872')
# AnswerResult(text='Snape', score=0.3666')
# AnswerResult(text='Rowling', score=0.5828')
# AnswerResult(text='C. S. Lewis', score=0.6034')
# AnswerResult(text='Hermione Granger', score=0.9353')
# AnswerResult(text='Quirrell', score=0.2198')
# AnswerResult(text='Quirrell', score=0.4884')
# AnswerResult(text='Rowling', score=0.2713')
# AnswerResult(text='Viktor Golyshev', score=0.8130')
# AnswerResult(text='Rowling', score=0.4030')
# AnswerResult(text='Rowling', score=0.4581')
# AnswerResult(text='A. S. Byatt', score=0.4862')
# AnswerResult(text='Fay Weldon', score=0.4716')
# AnswerResult(text='Chris Suellentrop', score=0.2245')
# AnswerResult(text='Andrew Blake', score=0.3916')
# AnswerResult(text='Andrew Blake', score=0.6446')
# AnswerResult(text='Nancy Stouffer', score=0.8797')
# AnswerResult(text='Philip Pullman', score=0.6295')
# AnswerResult(text='Rowling', score=0.7915')
# AnswerResult(text='Rowling', score=0.3398')
# 🏆 Best answer: J. K. Rowling with score 0.2300
# ✅ Exporting: ["Who is the author of 'Harry Potter'?", 'J. K. Rowling', 'J.K. Rowling']
#
# ❓ Question: What is the currency used in the United Kingdom?
# Found the following relevant Wikipedia documents: ['Reserve currency', 'Potential re-accession of the United Kingdom to the European Union', 'Pound sterling']
#
# 🔍 Attempting to fetch page: Reserve currency
# 📄 Page Retrieved: Reserve currency (Page ID: 177666)
# 🔍 Total chunks to evaluate: 15
# AnswerResult(text='Pound Sterling', score=0.7940')
# AnswerResult(text='Sterling', score=0.2188')
# AnswerResult(text='Pound Sterling', score=0.2201')
# 🔍 Attempting to fetch page: Potential re-accession of the United Kingdom to the European Union
# 📄 Page Retrieved: Potential re-accession of the United Kingdom to the European Union (Page ID: 67309211)
# ...
#
# ❓ Question: Who composed the 'Fifth Symphony'?
# Found the following relevant Wikipedia documents: ['Symphony No. 5 (Beethoven)', 'Symphony No. 6 (Beethoven)', 'Symphony No. 3 (Beethoven)']
#
# 🔍 Attempting to fetch page: Symphony No. 5 (Beethoven)
# 📄 Page Retrieved: Symphony No. 5 (Beethoven) (Page ID: 33687194)
# 🔍 Total chunks to evaluate: 24
# AnswerResult(text='Ludwig Van Beethoven', score=0.9190')
# AnswerResult(text='Beethoven', score=0.3393')
# AnswerResult(text='Beethoven', score=0.8756')
# AnswerResult(text='Courtenay Edward Stevens', score=0.6161')
# AnswerResult(text='Anton Schindler', score=0.7614')
# AnswerResult(text='Beethoven', score=0.4053')
# AnswerResult(text='Beethoven', score=0.5128')
# AnswerResult(text='Beethoven', score=0.8111')
# AnswerResult(text='Franz Liszt', score=0.9701')
# AnswerResult(text='Beethoven', score=0.7487')
# AnswerResult(text='Eroica Skbk', score=0.7693')
# 🔍 Attempting to fetch page: Symphony No. 6 (Beethoven)
# 📄 Page Retrieved: Symphony No. 6 (Beethoven) (Page ID: 507914)
# 🔍 Total chunks to evaluate: 7
# AnswerResult(text='Ludwig Van Beethoven', score=0.9737')
# AnswerResult(text='Justin Heinrich Knecht', score=0.7040')
# AnswerResult(text='Anton Bruckner', score=0.6366')
# AnswerResult(text='Beethoven', score=0.3592')
# 🔍 Attempting to fetch page: Symphony No. 3 (Beethoven)
# 📄 Page Retrieved: Symphony No. 3 (Beethoven) (Page ID: 242291)
# 🔍 Total chunks to evaluate: 28
# AnswerResult(text='Mozart', score=0.4640')
# AnswerResult(text='Beethoven', score=0.3737')
# AnswerResult(text='Ferdinand Ries', score=0.3269')
# AnswerResult(text='Beethoven', score=0.2598')
# AnswerResult(text='Fabrizio Della Seta', score=0.6645')
# AnswerResult(text='W. A. Mozart', score=0.5098')
# AnswerResult(text='Ferdinand Ries', score=0.2079')
# AnswerResult(text='Prince Lobkowitz', score=0.2449')
# AnswerResult(text='Beethoven', score=0.2436')
# AnswerResult(text='Beethoven', score=0.2218')
# 🏆 Best answer: Beethoven with score 0.4010
# ✅ Exporting: ["Who composed the 'Fifth Symphony'?", 'Beethoven', 'The Fifth Symphony was composed by Ludwig van Beethoven.']
#
# ❓ Question: What is the largest island in the world?
# Found the following relevant Wikipedia documents: ['List of islands by area', 'List of largest mosques', 'Largest organisms']
#
# 🔍 Attempting to fetch page: List of islands by area
# 📄 Page Retrieved: List of islands by area (Page ID: 330163)
# 🔍 Total chunks to evaluate: 1
# 🔍 Attempting to fetch page: List of largest mosques
# 📄 Page Retrieved: List of largest mosques (Page ID: 20897194)
# 🔍 Total chunks to evaluate: 1
# 🔍 Attempting to fetch page: Largest organisms
# 📄 Page Retrieved: Largest organisms (Page ID: 20598041)
# 🔍 Total chunks to evaluate: 7
# ❌ No valid answers found in any pages.
# ✅ Exporting: ['What is the largest island in the world?', 'No valid Wikipedia answer found', 'Greenland is the largest island in the world.']
#
# ❓ Question: What is the smallest prime number?
# Found the following relevant Wikipedia documents: ['Prime number', 'Mersenne prime', '101 (number)']
#
# 🔍 Attempting to fetch page: Prime number
# 📄 Page Retrieved: Prime number (Page ID: 23666)
# 🔍 Total chunks to evaluate: 57
# AnswerResult(text='2', score=0.2124')
# AnswerResult(text='2
#
#             16
#
#
#
#
#     {\Displaystyle 2^{16}}', score=0.3410')
# 🔍 Attempting to fetch page: Mersenne prime
# 📄 Page Retrieved: Mersenne prime (Page ID: 18908)
# 🔍 Total chunks to evaluate: 38
# AnswerResult(text='211 − 1 = 2047 = 23 × 89', score=0.8462')
# AnswerResult(text='211 − 1 = 2047 = 23 × 89', score=0.5506')
# AnswerResult(text='P', score=0.2749')
# AnswerResult(text='M1277', score=0.5313')
# AnswerResult(text='M1277', score=0.7443')
# 🔍 Attempting to fetch page: 101 (number)
# 📄 Page Retrieved: 101 (number) (Page ID: 407354)
# 🔍 Total chunks to evaluate: 4
# AnswerResult(text='101', score=0.3463')
# 🏆 Best answer: 211 − 1 = 2047 = 23 × 89 with score 0.3069
# ✅ Exporting: ['What is the smallest prime number?', '211 − 1 = 2047 = 23 × 89', 'The smallest prime number is 2.']
#
# ❓ Question: Who was the first woman to win a Nobel Prize?
# Found the following relevant Wikipedia documents: ['2024 Nobel Prize in Literature', 'List of Muslim Nobel laureates', 'Maria Skłodowska-Curie Monument (Ochota)']
#
# 🔍 Attempting to fetch page: 2024 Nobel Prize in Literature
# 📄 Page Retrieved: 2024 Nobel Prize in Literature (Page ID: 75098159)
# 🔍 Total chunks to evaluate: 7
# AnswerResult(text='Han Kang', score=0.7179')
# AnswerResult(text='Han Kang', score=0.5725')
# AnswerResult(text='Han Kang', score=0.2065')
# AnswerResult(text='Han Kang', score=0.3508')
# 🔍 Attempting to fetch page: List of Muslim Nobel laureates
# 📄 Page Retrieved: List of Muslim Nobel laureates (Page ID: 33332159)
# 🔍 Total chunks to evaluate: 5
# 🔍 Attempting to fetch page: Maria Skłodowska-Curie Monument (Ochota)
# 📄 Page Retrieved: Maria Skłodowska-Curie Monument (Ochota) (Page ID: 77791326)
# 🔍 Total chunks to evaluate: 2
# 🏆 Best answer: Han Kang with score 1.0000
# ✅ Exporting: ['Who was the first woman to win a Nobel Prize?', 'Han Kang', 'Marie Curie was the first woman to win a Nobel Prize. She won the Nobel Prize in Physics in 1903, and then went on to win a second Nobel Prize in Chemistry in 1911.']
#
# ❓ Question: Which planet is known as the Red Planet?
# Found the following relevant Wikipedia documents: ['Terrestrial planet', 'Planet Nine', 'Captain Planet and the Planeteers']
#
# 🔍 Attempting to fetch page: Terrestrial planet
# 📄 Page Retrieved: Terrestrial planet (Page ID: 48510)
# 🔍 Total chunks to evaluate: 12
# 🔍 Attempting to fetch page: Planet Nine
# 📄 Page Retrieved: Planet Nine (Page ID: 49168255)
# 🔍 Total chunks to evaluate: 56
# 🔍 Attempting to fetch page: Captain Planet and the Planeteers
# 📄 Page Retrieved: Captain Planet and the Planeteers (Page ID: 492218)
# 🔍 Total chunks to evaluate: 23
# ❌ No valid answers found in any pages.
# ✅ Exporting: ['Which planet is known as the Red Planet?', 'No valid Wikipedia answer found', 'Mars']
#
# ❓ Question: What is the largest continent by area?
# Found the following relevant Wikipedia documents: ['List of islands by area', 'List of countries and dependencies by area', 'Continent']
#
# 🔍 Attempting to fetch page: List of islands by area
# 📄 Page Retrieved: List of islands by area (Page ID: 330163)
# 🔍 Total chunks to evaluate: 1
# 🔍 Attempting to fetch page: List of countries and dependencies by area
# 📄 Page Retrieved: List of countries and dependencies by area (Page ID: 3989609)
# 🔍 Total chunks to evaluate: 2
# 🔍 Attempting to fetch page: Continent
# 📄 Page Retrieved: Continent (Page ID: 19630739)
# 🔍 Total chunks to evaluate: 25
# AnswerResult(text='Europe', score=0.5475')
# AnswerResult(text='Europe', score=0.8605')
# 🏆 Best answer: Europe with score 1.0000
# ✅ Exporting: ['What is the largest continent by area?', 'Europe', 'The largest continent by area is Asia.']
#
# ❓ Question: Who invented the World Wide Web?
# Found the following relevant Wikipedia documents: ['World Wide Web', 'History of the World Wide Web', 'June']
#
# 🔍 Attempting to fetch page: World Wide Web
# 📄 Page Retrieved: World Wide Web (Page ID: 33139)
# 🔍 Total chunks to evaluate: 36
# AnswerResult(text='Tim Berners-Lee', score=0.9546')
# AnswerResult(text='Berners-Lee', score=0.8348')
# AnswerResult(text='Berners-Lee', score=0.6746')
# 🔍 Attempting to fetch page: History of the World Wide Web
# 📄 Page Retrieved: History of the World Wide Web (Page ID: 4192777)
# 🔍 Total chunks to evaluate: 34
# AnswerResult(text='Tim Berners-Lee', score=0.9835')
# AnswerResult(text='Robert Cailliau', score=0.4883')
# AnswerResult(text='Tim Berners-Lee', score=0.3089')
# AnswerResult(text='Tim Berners-Lee', score=0.9701')
# 🔍 Attempting to fetch page: June
# 📄 Page Retrieved: June (Page ID: 15785)
# 🔍 Total chunks to evaluate: 16
# AnswerResult(text='Tim Berners-Lee', score=0.9533')
# AnswerResult(text='Tim Berners-Lee', score=0.9754')
# 🏆 Best answer: Tim Berners-Lee with score 0.7111
# ✅ Exporting: ['Who invented the World Wide Web?', 'Tim Berners-Lee', 'The World Wide Web was invented by British computer scientist Tim Berners-Lee in 1989.']
#
# ❓ Question: What is the primary language spoken in Egypt?
# Found the following relevant Wikipedia documents: ['Egyptian language', 'Coptic language', 'Egyptian Arabic']
#
# 🔍 Attempting to fetch page: Egyptian language
# 📄 Page Retrieved: Egyptian language (Page ID: 46918)
# 🔍 Total chunks to evaluate: 40
# AnswerResult(text='Arabic', score=0.9918')
# AnswerResult(text='Afroasiatic', score=0.2139')
# AnswerResult(text='Middle Egyptian', score=0.2718')
# AnswerResult(text='Coptic', score=0.3149')
# AnswerResult(text='Afroasiatic', score=0.8385')
# AnswerResult(text='Coptic', score=0.6137')
# AnswerResult(text='Coptic', score=0.4166')
# AnswerResult(text='Coptic', score=0.6429')
# AnswerResult(text='Coptic', score=0.8926')
# AnswerResult(text='Coptic', score=0.8555')
# AnswerResult(text='Afroasiatic', score=0.3546')
# AnswerResult(text='Afroasiatic', score=0.7073')
# AnswerResult(text='Afroasiatic', score=0.8523')
# AnswerResult(text='Egyptian Arabic', score=0.4398')
# AnswerResult(text='Egyptian Arabic', score=0.3026')
# AnswerResult(text='Coptic', score=0.2171')
# AnswerResult(text='Hebrew', score=0.2560')
# AnswerResult(text='Hebrew', score=0.6833')
# 🔍 Attempting to fetch page: Coptic language
# 📄 Page Retrieved: Coptic language (Page ID: 48473)
# 🔍 Total chunks to evaluate: 42
# AnswerResult(text='Arabic', score=0.8315')
# AnswerResult(text='Sahidic', score=0.2397')
# AnswerResult(text='Egyptian Arabic', score=0.3912')
# AnswerResult(text='Greek-Coptic', score=0.7541')
# AnswerResult(text='Coptic', score=0.4096')
# AnswerResult(text='Demotic', score=0.4092')
# AnswerResult(text='Demotic', score=0.4229')
# AnswerResult(text='Arabic', score=0.5128')
# AnswerResult(text='Arabic', score=0.9472')
# AnswerResult(text='Coptic', score=0.2314')
# AnswerResult(text='Arabic', score=0.7216')
# AnswerResult(text='Fusional', score=0.3436')
# AnswerResult(text='Coptic', score=0.3582')
# AnswerResult(text='Coptic', score=0.3864')
# AnswerResult(text='Coptic', score=0.4489')
# AnswerResult(text='Coptic', score=0.2204')
# AnswerResult(text='Coptic', score=0.8061')
# AnswerResult(text='Literary Old And Middle (Classical) Egyptian', score=0.2811')
# AnswerResult(text='Arabic', score=0.2526')
# AnswerResult(text='Coptic', score=0.5097')
# AnswerResult(text='Coptic Egyptian', score=0.2751')
# AnswerResult(text='Coptic', score=0.7802')
# AnswerResult(text='Coptic', score=0.3341')
# AnswerResult(text='Coptic, Sahidic, And Bashmuric', score=0.2862')
# AnswerResult(text='Hidice', score=0.2126')
# 🔍 Attempting to fetch page: Egyptian Arabic
# 📄 Page Retrieved: Egyptian Arabic (Page ID: 706816)
# 🔍 Total chunks to evaluate: 64
# AnswerResult(text='Egyptian Arabic', score=0.7133')
# AnswerResult(text='Arabic', score=0.2226')
# AnswerResult(text='Standard Arabic', score=0.6621')
# AnswerResult(text='Arabic', score=0.6406')
# AnswerResult(text='Sa'Idi Arabic', score=0.6393')
# AnswerResult(text='Arabic', score=0.4083')
# AnswerResult(text='Arabic', score=0.3115')
# AnswerResult(text='SaʽIdi Arabic', score=0.4167')
# AnswerResult(text='Sa'Īdi Arabic', score=0.3352')
# AnswerResult(text='Arabic', score=0.6246')
# AnswerResult(text='Arabic', score=0.2842')
# AnswerResult(text='Arabic', score=0.5651')
# AnswerResult(text='Arabic', score=0.9202')
# AnswerResult(text='Arabic', score=0.9922')
# AnswerResult(text='Arabic', score=0.8409')
# AnswerResult(text='Darrís', score=0.2233')
# AnswerResult(text='Arabic', score=0.8658')
# AnswerResult(text='Arabic', score=0.7789')
# AnswerResult(text='Arabic', score=0.8877')
# AnswerResult(text='Coptic', score=0.7985')
# AnswerResult(text='Classical Arabic', score=0.3379')
# AnswerResult(text='Arabic', score=0.3879')
# AnswerResult(text='Arabic', score=0.4232')
# AnswerResult(text='Arabic', score=0.3449')
# AnswerResult(text='Arabic', score=0.4690')
# AnswerResult(text='Fast Speech', score=0.2801')
# AnswerResult(text='Enough', score=0.3775')
# AnswerResult(text='Coptic', score=0.6548')
# AnswerResult(text='Levantine Arabic', score=0.3601')
# AnswerResult(text='Coptic', score=0.2969')
# AnswerResult(text='Arabic', score=0.2166')
# AnswerResult(text='Arabic', score=0.5928')
# AnswerResult(text='Arabic', score=0.2096')
# 🏆 Best answer: Arabic with score 0.3734
# ✅ Exporting: ['What is the primary language spoken in Egypt?', 'Arabic', 'The primary language spoken in Egypt is Arabic.']
#
# ❓ Question: What is the capital of Italy?
# Found the following relevant Wikipedia documents: ['Rome', 'Italy', 'Kingdom of Italy']
#
# 🔍 Attempting to fetch page: Rome
# 📄 Page Retrieved: Rome (Page ID: 25458)
# 🔍 Total chunks to evaluate: 72
# AnswerResult(text='Rome', score=0.9551')
# AnswerResult(text='Rome', score=0.9247')
# AnswerResult(text='Rome', score=0.5524')
# AnswerResult(text='Roma', score=0.9056')
# AnswerResult(text='Magna Graecia', score=0.7092')
# AnswerResult(text='Rome', score=0.2723')
# AnswerResult(text='Constantinople', score=0.6080')
# AnswerResult(text='Ravenna', score=0.4323')
# AnswerResult(text='Rome', score=0.6915')
# AnswerResult(text='Avignon', score=0.8147')
# AnswerResult(text='Florence', score=0.5266')
# AnswerResult(text='Vatican', score=0.2719')
# AnswerResult(text='Florence', score=0.9911')
# AnswerResult(text='Rome', score=0.4888')
# AnswerResult(text='Vatican Area', score=0.2986')
# AnswerResult(text='Rome', score=0.2094')
# AnswerResult(text='Taras', score=0.2678')
# AnswerResult(text='Taras', score=0.6508')
# AnswerResult(text='Rome', score=0.9455')
# AnswerResult(text='Rome', score=0.4757')
# AnswerResult(text='Rome', score=0.2831')
# AnswerResult(text='Rome', score=0.2789')
# AnswerResult(text='Vatican City', score=0.5181')
# AnswerResult(text='Papal', score=0.4752')
# AnswerResult(text='Rome', score=0.8218')
# AnswerResult(text='Rome', score=0.8752')
# AnswerResult(text='Rome', score=0.5112')
# AnswerResult(text='Rome', score=0.2253')
# AnswerResult(text='Rome', score=0.3282')
# AnswerResult(text='Rome', score=0.6437')
# AnswerResult(text='Rome', score=0.3429')
# AnswerResult(text='Rome', score=0.7099')
# AnswerResult(text='Rome', score=0.9200')
# AnswerResult(text='Rome', score=0.2350')
# AnswerResult(text='Rome', score=0.4103')
# AnswerResult(text='Rome', score=0.7703')
# AnswerResult(text='Rome', score=0.6895')
# AnswerResult(text='Rome', score=0.4401')
# AnswerResult(text='Rome', score=0.7419')
# AnswerResult(text='Rome', score=0.3369')
# AnswerResult(text='Civitavecchia', score=0.4104')
# 🔍 Attempting to fetch page: Italy
# 📄 Page Retrieved: Italy (Page ID: 14532)
# 🔍 Total chunks to evaluate: 78
# AnswerResult(text='Rome', score=0.9959')
# AnswerResult(text='Rome', score=0.4526')
# AnswerResult(text='Turin To Florence', score=0.3733')
# AnswerResult(text='Turin', score=0.2246')
# AnswerResult(text='Fiume', score=0.4531')
# AnswerResult(text='Rome', score=0.2470')
# AnswerResult(text='Paris', score=0.9893')
# AnswerResult(text='Rome', score=0.8260')
# AnswerResult(text='Genoa', score=0.9100')
# AnswerResult(text='Trieste', score=0.7333')
# AnswerResult(text='Rome', score=0.2922')
# AnswerResult(text='Rome And Naples', score=0.8104')
# AnswerResult(text='Rome', score=0.5442')
# AnswerResult(text='Rome', score=0.4543')
# AnswerResult(text='Rome', score=0.4053')
# AnswerResult(text='Milan', score=0.5602')
# AnswerResult(text='Rome', score=0.8886')
# AnswerResult(text='Rome', score=0.7327')
# 🔍 Attempting to fetch page: Kingdom of Italy
# 📄 Page Retrieved: Kingdom of Italy (Page ID: 9804204)
# 🔍 Total chunks to evaluate: 75
# AnswerResult(text='Rome', score=0.6220')
# AnswerResult(text='Florence', score=0.4384')
# AnswerResult(text='Rome', score=0.9946')
# AnswerResult(text='Rome', score=0.9599')
# AnswerResult(text='Rome', score=0.5358')
# AnswerResult(text='Lira', score=0.4159')
# AnswerResult(text='Naples', score=0.4088')
# AnswerResult(text='Zara', score=0.9847')
# AnswerResult(text='Zara', score=0.6828')
# AnswerResult(text='Rome', score=0.6470')
# AnswerResult(text='Rome', score=0.7937')
# AnswerResult(text='Rome', score=0.2017')
# AnswerResult(text='Vatican City', score=0.9115')
# AnswerResult(text='Corsica', score=0.7737')
# AnswerResult(text='Trieste', score=0.3185')
# 🏆 Best answer: Rome with score 0.5924
# ✅ Exporting: ['What is the capital of Italy?', 'Rome', 'The capital of Italy is Rome.']
